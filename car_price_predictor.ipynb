# %% [markdown]
# # Car prediction

# %%
import pandas as pd
import numpy as np

# %%
car=pd.read_csv('quikr_car.csv')
car.head()
# Out:
#                                      name   company  year          Price  \
# 0    Hyundai Santro Xing XO eRLX Euro III   Hyundai  2007         80,000
# 1                 Mahindra Jeep CL550 MDI  Mahindra  2006       4,25,000
# 2              Maruti Suzuki Alto 800 Vxi    Maruti  2018  Ask For Price
# 3  Hyundai Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014       3,25,000
# 4        Ford EcoSport Titanium 1.5L TDCi      Ford  2014       5,75,000
#
#    kms_driven fuel_type
# 0  45,000 kms    Petrol
# 1      40 kms    Diesel
# 2  22,000 kms    Petrol
# 3  28,000 kms    Petrol
# 4  36,000 kms    Diesel

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 892 entries, 0 to 891
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        892 non-null    object
#  1   company     892 non-null    object
#  2   year        892 non-null    object
#  3   Price       892 non-null    object
#  4   kms_driven  840 non-null    object
#  5   fuel_type   837 non-null    object
# dtypes: object(6)
# memory usage: 41.9+ KB

# %%
car['year'].unique()
# Out:
# array(['2007', '2006', '2018', '2014', '2015', '2012', '2013', '2016',
#        '2010', '2017', '2008', '2011', '2019', '2009', '2005', '2000',
#        '...', '150k', 'TOUR', '2003', 'r 15', '2004', 'Zest', '/-Rs',
#        'sale', '1995', 'ara)', '2002', 'SELL', '2001', 'tion', 'odel',
#        '2 bs', 'arry', 'Eon', 'o...', 'ture', 'emi', 'car', 'able', 'no.',
#        'd...', 'SALE', 'digo', 'sell', 'd Ex', 'n...', 'e...', 'D...',
#        ', Ac', 'go .', 'k...', 'o c4', 'zire', 'cent', 'Sumo', 'cab',
#        't xe', 'EV2', 'r...', 'zest'], dtype=object)

# %%
backup=car.copy()

# %%
car=car[car['year'].str.isnumeric()]

# %%
car['year']=car['year'].astype(int)

# %%
car.head()
# Out:
#                                      name   company  year          Price  \
# 0    Hyundai Santro Xing XO eRLX Euro III   Hyundai  2007         80,000
# 1                 Mahindra Jeep CL550 MDI  Mahindra  2006       4,25,000
# 2              Maruti Suzuki Alto 800 Vxi    Maruti  2018  Ask For Price
# 3  Hyundai Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014       3,25,000
# 4        Ford EcoSport Titanium 1.5L TDCi      Ford  2014       5,75,000
#
#    kms_driven fuel_type
# 0  45,000 kms    Petrol
# 1      40 kms    Diesel
# 2  22,000 kms    Petrol
# 3  28,000 kms    Petrol
# 4  36,000 kms    Diesel

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 842 entries, 0 to 891
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        842 non-null    object
#  1   company     842 non-null    object
#  2   year        842 non-null    int32
#  3   Price       842 non-null    object
#  4   kms_driven  840 non-null    object
#  5   fuel_type   837 non-null    object
# dtypes: int32(1), object(5)
# memory usage: 42.8+ KB

# %%
car=car[car['Price']!="Ask For price"]

# %%
car['Price']=car['Price'].str.replace(',','')

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 842 entries, 0 to 891
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        842 non-null    object
#  1   company     842 non-null    object
#  2   year        842 non-null    int32
#  3   Price       842 non-null    object
#  4   kms_driven  840 non-null    object
#  5   fuel_type   837 non-null    object
# dtypes: int32(1), object(5)
# memory usage: 42.8+ KB

# %%
car['Price']=car['Price'].astype(int)

# %%
car=car[car['Price']!='Ask For Price']

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17 entries, 1 to 762
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        17 non-null     object
#  1   company     17 non-null     object
#  2   year        17 non-null     int32
#  3   Price       17 non-null     int32
#  4   kms_driven  17 non-null     int32
#  5   fuel_type   17 non-null     object
# dtypes: int32(3), object(3)
# memory usage: 748.0+ bytes

# %%
car['kms_driven']=car['kms_driven'].str.split(' ').str.get(0).str.replace(',',' ')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[74], line 1
# ----> 1 car['kms_driven']=car['kms_driven'].str.split(' ').str.get(0).str.replace(',',' ')
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:6296, in NDFrame.__getattr__(self, name)
#    6289 if (
#    6290     name not in self._internal_names_set
#    6291     and name not in self._metadata
#    6292     and name not in self._accessors
#    6293     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6294 ):
#    6295     return self[name]
# -> 6296 return object.__getattribute__(self, name)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\accessor.py:224, in CachedAccessor.__get__(self, obj, cls)
#     221 if obj is None:
#     222     # we're accessing the attribute of the class, i.e., Dataset.geo
# ...

# %%
car=car[car['kms_driven'].str.isnumeric()]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[75], line 1
# ----> 1 car=car[car['kms_driven'].str.isnumeric()]
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:6296, in NDFrame.__getattr__(self, name)
#    6289 if (
#    6290     name not in self._internal_names_set
#    6291     and name not in self._metadata
#    6292     and name not in self._accessors
#    6293     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6294 ):
#    6295     return self[name]
# -> 6296 return object.__getattribute__(self, name)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\accessor.py:224, in CachedAccessor.__get__(self, obj, cls)
#     221 if obj is None:
#     222     # we're accessing the attribute of the class, i.e., Dataset.geo
#     223     return self._accessor
# ...

# %%
car['kms_driven']=car['kms_driven'].astype(int)

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17 entries, 1 to 762
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        17 non-null     object
#  1   company     17 non-null     object
#  2   year        17 non-null     int32
#  3   Price       17 non-null     object
#  4   kms_driven  17 non-null     int32
#  5   fuel_type   17 non-null     object
# dtypes: int32(2), object(4)
# memory usage: 816.0+ bytes

# %%
car=car[~car['fuel_type'].isna()]

# %%
car['name']=car['name'].str.split(' ').str.slice(0,3).str.join(' ')

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17 entries, 1 to 762
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        17 non-null     object
#  1   company     17 non-null     object
#  2   year        17 non-null     int32
#  3   Price       17 non-null     int32
#  4   kms_driven  17 non-null     int32
#  5   fuel_type   17 non-null     object
# dtypes: int32(3), object(3)
# memory usage: 748.0+ bytes

# %%
car.head()
# Out:
#                     name   company  year   Price  kms_driven fuel_type
# 1    Mahindra Jeep CL550  Mahindra  2006  425000          40    Diesel
# 15   Mahindra Jeep CL550  Mahindra  2006  425000          40    Diesel
# 215     Mahindra Jeep MM  Mahindra  2019  390000          60    Diesel
# 222  Mahindra Jeep CL550  Mahindra  2018  385000         588    Diesel
# 302  Maruti Suzuki Swift    Maruti  2019  610000          73    Petrol

# %%
car=car.reset_index(drop=True)

# %%
car.head()
# Out:
#                   name   company  year   Price  kms_driven fuel_type
# 0  Mahindra Jeep CL550  Mahindra  2006  425000          40    Diesel
# 1  Mahindra Jeep CL550  Mahindra  2006  425000          40    Diesel
# 2     Mahindra Jeep MM  Mahindra  2019  390000          60    Diesel
# 3  Mahindra Jeep CL550  Mahindra  2018  385000         588    Diesel
# 4  Maruti Suzuki Swift    Maruti  2019  610000          73    Petrol

# %%
car=pd.read_csv('Cleaned car.csv')
car.to_csv('Cleaned car.csv')

# %%
X=car.drop(columns='Price')
y=car['Price']

# %%
y
# Out:
# 1       425000
# 15      425000
# 215     390000
# 222     385000
# 302     610000
# 364     390000
# 381     385000
# 382     425000
# 387     770000
# 427    1200000
# 470     230000
# 485     650000
# 577     424000
# 702     525000
# 721     125000
# 738    1200000
# 762     568500
# Name: Price, dtype: object

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17 entries, 1 to 762
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        17 non-null     object
#  1   company     17 non-null     object
#  2   year        17 non-null     int32
#  3   Price       17 non-null     object
#  4   kms_driven  17 non-null     int32
#  5   fuel_type   17 non-null     object
# dtypes: int32(2), object(4)
# memory usage: 816.0+ bytes

# %%
X
# Out:
#                                        name   company  year  kms_driven  \
# 1                   Mahindra Jeep CL550 MDI  Mahindra  2006          40
# 15                  Mahindra Jeep CL550 MDI  Mahindra  2006          40
# 215                Mahindra Jeep MM 550 XDB  Mahindra  2019          60
# 222                 Mahindra Jeep CL550 MDI  Mahindra  2018         588
# 302   Maruti Suzuki Swift VXi 1.2 ABS BS IV    Maruti  2019          73
# 364                Mahindra Jeep MM 550 XDB  Mahindra  2019          60
# 381                 Mahindra Jeep CL550 MDI  Mahindra  2018         588
# 382                Mahindra Jeep MM 550 XDB  Mahindra  2006         122
# 387      Toyota Innova 2.5 E MS 7 STR BS IV    Toyota  2012           0
# 427           Nissan X Trail Select Variant    Nissan  2019         300
# 470      Maruti Suzuki Swift Dzire Tour VXi    Maruti  2011          65
# 485                  Tata Tigor Revotron XZ      Tata  2019         100
# ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test,y_train, y_test=train_test_split(X,y, test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import make_column_transformer
from sklearn.pipeline import make_pipeline

# %%
ohe=OneHotEncoder()
ohe.fit(X[['name','company','fuel_type']])
# Out:
# OneHotEncoder()

# %%
lr=LinearRegression()

# %%
pipe=make_pipeline(coloumn_trans,lr)
pipe.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(categories=[array(['Ford Figo Petrol Titanium', 'Hyundai Creta 1.6 SX',
#        'Mahindra Jeep CL550 MDI', 'Mahindra Jeep MM 550 XDB',
#        'Maruti Suzuki Swift Dzire Tour VXi',
#        'Maruti Suzuki Swift VXi 1.2 ABS BS IV',
#        'Maruti Suzuki Zen Estilo LXI Green CNG',
#        'Nissan X Trail Select Variant', 'Tata Tiago Revotorq XZ',
#        'Tata Tigor Revotron XZ', 'Toyota Innova 2.5 E MS 7 STR BS IV'],
#       dtype=object),
#                                                                             array(['Ford', 'Hyundai', 'Mahindra', 'Maruti', 'Nissan', 'Tata',
#        'Toyota'], dtype=object),
#                                                                             array(['Diesel', 'Petrol'], dtype=object)]),
# ...

# %%
coloumn_trans=make_column_transformer((OneHotEncoder(categories=ohe.categories_),['name','company','fuel_type']),
                                     remainder='passthrough')

# %%
pipe.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(categories=[array(['Ford Figo Petrol', 'Hyundai Creta 1.6', 'Mahindra Jeep CL550',
#        'Mahindra Jeep MM', 'Maruti Suzuki Swift', 'Maruti Suzuki Zen',
#        'Nissan X Trail', 'Tata Tiago Revotorq', 'Tata Tigor Revotron',
#        'Toyota Innova 2.5'], dtype=object),
#                                                                             array(['Ford', 'Hyundai', 'Mahindra', 'Maruti', 'Nissan', 'Tata',
#        'Toyota'], dtype=object),
#                                                                             array(['Diesel', 'Petrol'], dtype=object)]),
#                                                   ['name', 'company',
#                                                    'fuel_type'])])),
# ...

# %%
y_pred=pipe.predict(X_test)

# %%
y_pred
# Out:
# array([ -61856.50887574,  425000.00000001, 2178798.81656805,
#        2178798.81656805])

# %%
r2_score(y_test,y_pred)
# Out:
# -4169.286030547829

# %%
for i in range(1000):
    scores=[]
    X_train, X_test,y_train, y_test=train_test_split(X,y, test_size=0.2,random_state=i)
    lr=LinearRegression()
    pipe=make_pipeline(coloumn_trans,lr)
    pipe.fit(X_train,y_train)
    y_pred=pipe.predict(X_test)
    scores.append(r2_score(y_test,y_pred))

# %%
np.argmax(scores)
# Out:
# 0

# %%
scores[np.argmax(scores)]
# Out:
# 0.25026451651754666

# %%
X_train, X_test,y_train, y_test=train_test_split(X,y, test_size=0.2,random_state=np.argmax(scores))
lr=LinearRegression()
pipe=make_pipeline(coloumn_trans,lr)
pipe.fit(X_train,y_train)
y_pred=pipe.predict(X_test)
r2_score(y_test,y_pred)
# Out:
# -0.12590562605316924

# %%
import pickle

# %%
pickle.dump(pipe,open('LinearRegressionModel.pk1','wb'))

# %%
pipe.predict(pd.DataFrame([['Maruti Suzuki Swift VXi 1.2 ABS BS IV','Maruti',2019,100,'Petrol',]],columns=['name','company','year','kms_driven','fuel_type']))
# Out:
# array([609564.61500718])

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17 entries, 1 to 762
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        17 non-null     object
#  1   company     17 non-null     object
#  2   year        17 non-null     int32
#  3   Price       17 non-null     object
#  4   kms_driven  17 non-null     int32
#  5   fuel_type   17 non-null     object
# dtypes: int32(2), object(4)
# memory usage: 816.0+ bytes
